# %% [markdown]
# Neural Network Optimization #3

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from google.colab import drive
drive.mount('/content/drive')

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
# Mounted at /content/drive
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop non-beneficial columns
application_df = application_df.drop(['EIN', 'NAME', 'STATUS', 'SPECIAL_CONSIDERATIONS'], axis = 1)

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
cutoff = 5
application_types_to_replace = application_df['APPLICATION_TYPE'].value_counts()[application_df['APPLICATION_TYPE'].value_counts() < cutoff].index.tolist()
# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# T13         66
# T12         27
# T2          16
# Other       11
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
cutoff = 5
classifications_to_replace = application_df['CLASSIFICATION'].value_counts()[application_df['CLASSIFICATION'].value_counts() < cutoff].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# Other       45
# C1230       36
# C1400       34
# C2300       32
# C7200       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C6000       15
# C1800       15
# C1250       14
# C8200       11
# C1278       10
# C1238       10
# C1235        9
# C1237        9
# C7210        7
# C4100        6
# C1720        6
# C2400        6
# C1257        5
# C1600        5
# Name: count, dtype: int64

# %%
# application_df = application_df.drop(['APPLICATION_TYPE'],axis=1)
# Convert categorical data to numeric with `pd.get_dummies`
application_encoded_df = pd.get_dummies(application_df).astype(int)

# %%
# Split our preprocessed data into our features and target arrays
X = application_encoded_df.drop(['IS_SUCCESSFUL'], axis=1)
y = application_encoded_df['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

nn3 = tf.keras.models.Sequential()

# First hidden layer
nn3.add(tf.keras.layers.Dense(units=512, activation="relu", input_dim=X_train_scaled.shape[-1]))

# Second hidden layer
nn3.add(tf.keras.layers.Dense(units=256, activation="relu"))

# Output layer
nn3.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               39424
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 171009 (668.00 KB)
# Trainable params: 171009 (668.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
nn3.compile(loss="binary_crossentropy", optimizer=optimizer, metrics=["accuracy"])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

filepath = 'model_weights_epoch_{epoch:02d}.h5'

checkpoint_callback = ModelCheckpoint(filepath, save_weights_only = True, save_freq = 5)

# %%
# Train the model
fit_model = nn3.fit(X_train_scaled, y_train, epochs=50, callbacks = [checkpoint_callback])
# Out:
# Epoch 1/50
# 804/804 [==============================] - 9s 9ms/step - loss: 0.5741 - accuracy: 0.7205
# Epoch 2/50
# 804/804 [==============================] - 8s 10ms/step - loss: 0.5543 - accuracy: 0.7302
# Epoch 3/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5505 - accuracy: 0.7305
# Epoch 4/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5485 - accuracy: 0.7313
# Epoch 5/50
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5473 - accuracy: 0.7333
# Epoch 6/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5456 - accuracy: 0.7329
# Epoch 7/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5444 - accuracy: 0.7335
# Epoch 8/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5442 - accuracy: 0.7341
# Epoch 9/50
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5424 - accuracy: 0.7343
# Epoch 10/50
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5422 - accuracy: 0.7353
# Epoch 11/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5421 - accuracy: 0.7350
# Epoch 12/50
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5420 - accuracy: 0.7351
# Epoch 13/50
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5410 - accuracy: 0.7355
# Epoch 14/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5405 - accuracy: 0.7355
# Epoch 15/50
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5401 - accuracy: 0.7355
# Epoch 16/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5402 - accuracy: 0.7372
# Epoch 17/50
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5400 - accuracy: 0.7362
# Epoch 18/50
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5388 - accuracy: 0.7372
# Epoch 19/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5385 - accuracy: 0.7359
# Epoch 20/50
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5387 - accuracy: 0.7368
# Epoch 21/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5380 - accuracy: 0.7369
# Epoch 22/50
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5380 - accuracy: 0.7376
# Epoch 23/50
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5379 - accuracy: 0.7365
# Epoch 24/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5377 - accuracy: 0.7371
# Epoch 25/50
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5374 - accuracy: 0.7373
# Epoch 26/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5369 - accuracy: 0.7371
# Epoch 27/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5366 - accuracy: 0.7381
# Epoch 28/50
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5363 - accuracy: 0.7407
# Epoch 29/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5365 - accuracy: 0.7390
# Epoch 30/50
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5365 - accuracy: 0.7387
# Epoch 31/50
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5362 - accuracy: 0.7385
# Epoch 32/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5362 - accuracy: 0.7377
# Epoch 33/50
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5357 - accuracy: 0.7390
# Epoch 34/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5358 - accuracy: 0.7398
# Epoch 35/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5351 - accuracy: 0.7392
# Epoch 36/50
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5355 - accuracy: 0.7380
# Epoch 37/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5350 - accuracy: 0.7386
# Epoch 38/50
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5347 - accuracy: 0.7408
# Epoch 39/50
# 804/804 [==============================] - 5s 7ms/step - loss: 0.5350 - accuracy: 0.7390
# Epoch 40/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5348 - accuracy: 0.7396
# Epoch 41/50
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5348 - accuracy: 0.7395
# Epoch 42/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5343 - accuracy: 0.7402
# Epoch 43/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5342 - accuracy: 0.7393
# Epoch 44/50
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5342 - accuracy: 0.7389
# Epoch 45/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5338 - accuracy: 0.7402
# Epoch 46/50
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5335 - accuracy: 0.7421
# Epoch 47/50
# 804/804 [==============================] - 6s 7ms/step - loss: 0.5336 - accuracy: 0.7405
# Epoch 48/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5333 - accuracy: 0.7391
# Epoch 49/50
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5335 - accuracy: 0.7395
# Epoch 50/50
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5332 - accuracy: 0.7393

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn3.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5524 - accuracy: 0.7315 - 570ms/epoch - 2ms/step
# Loss: 0.5524207353591919, Accuracy: 0.7315452098846436

# %%
# Export our model to HDF5 file
nn3.save("/content/drive/MyDrive/Colab Notebooks/AlphabetSoupCharity_Optimization3.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
